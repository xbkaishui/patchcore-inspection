# %%
from PIL import Image
import torch
from torchvision import transforms
from PyNomaly import loop
import time
from loguru import logger
import cv2
import numpy as np

# %%
img_path = "old-0100-B.jpg" 
image = Image.open(img_path)

# %%
img_np = np.array(image)
img_np.shape
# Out:
# (484, 424, 3)

# %%
resize = 484
tf_resize = transforms.Resize([resize,resize])

# %%
img = tf_resize(image)
type(img)
np.array(img).shape
# Out:
# (484, 484, 3)

# %%
# img
# Out:
# <PIL.Image.Image image mode=RGB size=484x484>
